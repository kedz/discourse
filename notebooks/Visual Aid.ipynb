# %%
import discourse.data as data
#import discourse.inference.perceptron as perceptron
from  discourse.models.rush import RushModel
import corenlp_xml as cnlp
from collections import defaultdict
from discourse.hypergraph import recover_order
from os import makedirs, getenv, remove
from os.path import join, exists
import pygraphviz as pgv
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-59e230145e14> in <module>()
#       1 import discourse.data as data
#       2 #import discourse.inference.perceptron as perceptron
# ----> 3 from  discourse.models.rush import RushModel
#       4 import corenlp_xml as cnlp
#       5 from collections import defaultdict
#
# /home/chris/projects/discourse/latest/discourse/discourse/models/rush.py in <module>()
#       1 import corenlp_xml as cnlp
#       2 from collections import deque, defaultdict
# ----> 3 from discourse.hypergraph import s2i
#       4 import discourse.gazetteers as gazetteers
#       5 import itertools
#
# /home/chris/projects/discourse/latest/discourse/discourse/hypergraph.py in <module>()
# ----> 1 import pydecode.hyper as ph
#       2 import pydecode.chart as chart
#       3 import itertools
#       4 from collections import namedtuple
#       5
#
# /home/chris/projects/sasha/PyDecode/python/pydecode/hyper.py in <module>()
# ----> 1 from pydecode.hypergraph import *
#       2 from pydecode.potentials import *
#       3 #from pydecode.beam import *
#
# /usr/local/lib/python2.7/dist-packages/pyximport/pyximport.pyc in load_module(self, fullname)
#     429                                  self.pyxbuild_dir,
#     430                                  build_inplace=self.inplace,
# --> 431                                  language_level=self.language_level)
#     432         return module
#     433
#
# /usr/local/lib/python2.7/dist-packages/pyximport/pyximport.pyc in load_module(name, pyxfilename, pyxbuild_dir, is_package, build_inplace, language_level, so_path)
#     207                 module_name = name
#     208             so_path = build_module(module_name, pyxfilename, pyxbuild_dir,
# --> 209                                    inplace=build_inplace, language_level=language_level)
#     210         mod = imp.load_dynamic(name, so_path)
#     211         if is_package and not hasattr(mod, '__path__'):
#
# /usr/local/lib/python2.7/dist-packages/pyximport/pyximport.pyc in build_module(name, pyxfilename, pyxbuild_dir, inplace, language_level)
#     184                                   setup_args=sargs,
#     185                                   inplace=inplace,
# --> 186                                   reload_support=pyxargs.reload_support)
#     187     assert os.path.exists(so_path), "Cannot find: %s" % so_path
#     188
#
# /usr/local/lib/python2.7/dist-packages/pyximport/pyxbuild.pyc in pyx_to_dll(filename, ext, force_rebuild, build_in_temp, pyxbuild_dir, setup_args, reload_support, inplace)
#     102     try:
#     103         obj_build_ext = dist.get_command_obj("build_ext")
# --> 104         dist.run_commands()
#     105         so_path = obj_build_ext.get_outputs()[0]
#     106         if obj_build_ext.inplace:
#
# /usr/lib/python2.7/distutils/dist.pyc in run_commands(self)
#     951         """
#     952         for cmd in self.commands:
# --> 953             self.run_command(cmd)
#     954
#     955     # -- Methods that operate on its Commands --------------------------
#
# /usr/lib/python2.7/distutils/dist.pyc in run_command(self, command)
#     970         cmd_obj = self.get_command_obj(command)
#     971         cmd_obj.ensure_finalized()
# --> 972         cmd_obj.run()
#     973         self.have_run[command] = 1
#     974
#
# /usr/local/lib/python2.7/dist-packages/Cython/Distutils/build_ext.pyc in run(self)
#     161             optimization.disable_optimization()
#     162
# --> 163         _build_ext.build_ext.run(self)
#     164
#     165     def build_extensions(self):
#
# /usr/lib/python2.7/distutils/command/build_ext.pyc in run(self)
#     337
#     338         # Now actually compile and link everything.
# --> 339         self.build_extensions()
#     340
#     341     def check_extensions_list(self, extensions):
#
# /usr/local/lib/python2.7/dist-packages/Cython/Distutils/build_ext.pyc in build_extensions(self)
#     169         for ext in self.extensions:
#     170             ext.sources = self.cython_sources(ext.sources, ext)
# --> 171             self.build_extension(ext)
#     172
#     173     def cython_sources(self, sources, extension):
#
# /usr/lib/python2.7/distutils/command/build_ext.pyc in build_extension(self, ext)
#     496                                          debug=self.debug,
#     497                                          extra_postargs=extra_args,
# --> 498                                          depends=ext.depends)
#     499
#     500         # XXX -- this is a Vile HACK!
#
# /usr/lib/python2.7/distutils/ccompiler.pyc in compile(self, sources, output_dir, macros, include_dirs, debug, extra_preargs, extra_postargs, depends)
#     570             except KeyError:
#     571                 continue
# --> 572             self._compile(obj, src, ext, cc_args, extra_postargs, pp_opts)
#     573
#     574         # Return *all* object filenames, not just the ones we just built.
#
# /usr/lib/python2.7/distutils/unixccompiler.pyc in _compile(self, obj, src, ext, cc_args, extra_postargs, pp_opts)
#     178                        extra_postargs)
#     179         except DistutilsExecError, msg:
# --> 180             raise CompileError, msg
#     181
#     182     def create_static_lib(self, objects, output_libname,
#
# ImportError: Building module pydecode.hypergraph failed: ["CompileError: command 'gcc' failed with exit status 1\n"]
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         if self.thisptr is not NULL:
#             _hypergraph_registry_counts[self.thisptr.id()] -= 1
#             #print "LOWERING", self.thisptr.id(), _hypergraph_registry_counts[self.thisptr.id()]
#             if _hypergraph_registry_counts[self.thisptr.id()] == 0:
#                 #print "DEALLOCATING", self.thisptr.id()
#                 del self.thisptr
#                ^
# ------------------------------------------------------------
#
# /home/chris/projects/sasha/PyDecode/python/pydecode/hypergraph.pyx:45:16: Operation only allowed in c++
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
#         Returns
#         ---------------------
#         :py:class:`GraphBuilder`
#         """
#         self.thisptr = new CHypergraph()
#                           ^
# ------------------------------------------------------------
#
# /home/chris/projects/sasha/PyDecode/python/pydecode/hypergraph.pyx:77:27: Operation only allowed in c++
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     The edges :math:`e \in {\cal E}` with :math:`y(e) = 1`.
#
#     """
#
#     def __dealloc__(self):
#         del self.thisptr
#        ^
# ------------------------------------------------------------
#
# /home/chris/projects/sasha/PyDecode/python/pydecode/hypergraph.pyx:388:8: Operation only allowed in c++
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         self.graph = graph
#         edges.sort(key=lambda e:e.id)
#         if graph and edges:
#             for edge in edges:
#                 cedges.push_back((<Edge>edge).edgeptr)
#             self.thisptr = new CHyperpath(graph.thisptr, cedges)
#                               ^
# ------------------------------------------------------------
#
# /home/chris/projects/sasha/PyDecode/python/pydecode/hypergraph.pyx:400:31: Operation only allowed in c++

# %%
xmls = [xml for xml in data.corenlp_apws_train()]
doc = cnlp.Document(xmls[40])
model = RushModel(doc, history=2)
for s in doc:
    print s
# Out:
# STRING FAILED: XXXX-WXX-3TMO
# STRING FAILED: XXXX-WXX-3TMO
# STRING FAILED: XXXX-WXX-3TMO
# A moderate earthquake shook the western town of Dinar early Wednesday morning , three weeks after a strong quake destroyed most of the town and killed 90 people .
# There were no reports of damage or casualties after Wednesday 's quake which had a preliminary magnitude of 3.7 .
# The epicenter was very close to Dinar , Kandilli observatory in Istanbul said .

# %%
trans = model.gold_transitions()
order = recover_order(model.gold_transitions())

G = pgv.AGraph()
nsents = len(order)
for i, sindex in enumerate(order):
    for j, w in enumerate(doc[sindex]):
        G.add_node('{}x{} {}'.format(sindex, j, w.word), shape='box', fontsize='10.0', pos='{},{}!'.format(j*1.5, nsents - i))


for tran in trans:
    model.feature_map(tran)
    feats = model._t
    for feat in feats:
        #print feat
        indices = feat[1]
        s0 = indices[0][0]
        w0 = indices[0][1]
        s1 = indices[1][0]
        w1 = indices[1][1]
        n0 = '{}x{} {}'.format(s0, w0, doc[s0][w0].word)
        n1 = '{}x{} {}'.format(s1, w1, doc[s1][w1].word)
        
        G.add_edge(n0, n1, label=feat[0])
    
G.layout(prog='neato')
G.draw('/tmp/toctree.png')
from IPython.display import Image
Image(filename='/tmp/toctree.png')

# %%
trans = model.gold_transitions()[1]
print trans
order = recover_order(model.gold_transitions())
print order
model.feature_map(trans)
feats = model._t
# Out:
# sent-0 -> sent-1
# [0, 1]
# [1, 0]
# An earthquake of 4.5 magnitude hit midwest Nepal on Thursday , but no damage to buildings or other injuries to people was reported , officials said .
#
# The quake hit Romakhani , 190 kilometers -LRB- 120 miles -RRB- northwest of capital Katmandu at 12:18 local time -LRB- 06:33 gmt -RRB- , according to seismologists here .
#
# earthquake nsubj
# 	quake nsubj
# here
# ('role0:nsubj det:a _ role1:nsubj det:the_subsumed:True', [(0, 1), (1, 1)])
# [('role0:nsubj det:a _ role1:nsubj det:the_subsumed:True', [(0, 1), (1, 1)])]
# magnitude prep_of
# []
# Nepal dobj
# []
# Thursday prep_on
# []
# damage nsubjpass
# []
# buildings prep_to
# []
# injuries prep_to
# []
# people prep_to
# []
# damage nsubjpass
# []
# buildings prep_to
# []
# injuries prep_to
# []
# people prep_to
# []
# officials nsubj
# []

# %%
G = pgv.AGraph()

nsents = len(order)
for i, sindex in enumerate(order):
    for j, w in enumerate(doc[sindex]):
        G.add_node('{}x{} {}'.format(sindex, j, w.word), shape='box', pos='{},{}!'.format(j*2, nsents - i))

for feat in feats:
    print feat
    indices = feat[1]
    s0 = indices[0][0]
    w0 = indices[0][1]
    s1 = indices[1][0]
    w1 = indices[1][1]
    n0 = '{}x{} {}'.format(s0, w0, doc[s0][w0].word)
    n1 = '{}x{} {}'.format(s1, w1, doc[s1][w1].word)
    
    G.add_edge(n0, n1, label=feat[0])
G.layout(prog='neato')
G.draw('/tmp/toctree.png')
from IPython.display import Image
Image(filename='/tmp/toctree.png')
# Out:
# ('role0:nsubj det:a _ role1:nsubj det:the_subsumed:True', [(0, 1), (1, 1)])

# %%
model = RushModel(doc, history=2, features=feats)
recover_order
import pygraphviz as pgv

sents = [['s1_A', 's1_dog', 's1_saw', 's1_a', 's1_cat'],
         ['s2_The', 's2_cat', 's2_is', 's2_fat.'],
         ['s3_What', 's3_a', 's3_dumb', 's3_cat.']]

G = pgv.AGraph()

nsents = len(sents)
for i, s in enumerate(sents, 1):
    for j, w in enumerate(s, 1):
        G.add_node(w, shape='box', pos='{},{}!'.format(j, nsents - i))
        
G.add_edge('s2_cat', 's3_cat.')
G.layout(prog='neato')
G.draw('/tmp/toctree.png')
from IPython.display import Image
Image(filename='/tmp/toctree.png')
